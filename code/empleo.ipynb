# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('../data/paro.csv', delimiter=';')
df
# Out:
#               Sexo Comunidades y Ciudades Autónomas           Edad Periodo  \
# 0      Ambos sexos                   Total Nacional          Total  2023T4
# 1      Ambos sexos                   Total Nacional          Total  2023T3
# 2      Ambos sexos                   Total Nacional          Total  2023T2
# 3      Ambos sexos                   Total Nacional          Total  2023T1
# 4      Ambos sexos                   Total Nacional          Total  2022T4
# ...            ...                              ...            ...     ...
# 36955      Mujeres                       19 Melilla  55 y más años  2003T1
# 36956      Mujeres                       19 Melilla  55 y más años  2002T4
# 36957      Mujeres                       19 Melilla  55 y más años  2002T3
# 36958      Mujeres                       19 Melilla  55 y más años  2002T2
# 36959      Mujeres                       19 Melilla  55 y más años  2002T1
#
#        Total
# 0      11,76
# 1      11,84
# 2      11,60
# ...

# %%
df1 = pd.read_csv('../data/salario_medio_deciles_sexo_comunidad.csv', delimiter=';')
df1
# Out:
#              Sexo Comunidades autónomas Medidas y percentiles  Periodo  \
# 0     Ambos sexos        Total Nacional                 Media     2021
# 1     Ambos sexos        Total Nacional                 Media     2020
# 2     Ambos sexos        Total Nacional                 Media     2019
# 3     Ambos sexos        Total Nacional                 Media     2018
# 4     Ambos sexos        Total Nacional                 Media     2017
# ...           ...                   ...                   ...      ...
# 4531      Hombres             Rioja, La          Percentil 90     2012
# 4532      Hombres             Rioja, La          Percentil 90     2011
# 4533      Hombres             Rioja, La          Percentil 90     2010
# 4534      Hombres             Rioja, La          Percentil 90     2009
# 4535      Hombres             Rioja, La          Percentil 90     2008
#
#           Total
# 0     25.896,82
# 1     25.165,51
# 2     24.395,98
# 3     24.009,12
# 4      23.646,5
# ...

# %%
df1.Total.describe()
# Out:
# count     42240
# unique     6129
# top         0,3
# freq       2350
# Name: Total, dtype: object

# %%
df2 = pd.read_csv('../data/salario_medio_deciles_sexo_comunidad.csv', delimiter=';')
df2

# %%
sal = pd.read_csv('../data/CSV/EES_2018.csv', sep='\t')
sal
# Out:
#         IDENCCC  ORDENTRA  NUTS1 CNACE  ESTRATO2  CONTROL  MERCADO  \
# 0            25         1      1    H1         1        2        3
# 1            25         2      1    H1         1        2        3
# 2            25         3      1    H1         1        2        3
# 3            25         4      1    H1         1        2        3
# 4            25         5      1    H1         1        2        3
# ...         ...       ...    ...   ...       ...      ...      ...
# 216721    24676        21      7    P0         3        1        2
# 216722    24676        22      7    P0         3        1        2
# 216723    24676        23      7    P0         3        1        2
# 216724    24676        24      7    P0         3        1        2
# 216725    24676        25      7    P0         3        1        2
#
#         REGULACION  SEXO  TIPOPAIS CNO1  RESPONSA  ESTU  ANOANTI  MESANTI  \
# 0                2     1         1   N0         0     3       28       10
# ...

# %%
sal.sort_values(by='RETRINOIN')
sal
# Out:
#         IDENCCC  ORDENTRA  NUTS1 CNACE  ESTRATO2  CONTROL  MERCADO  \
# 0            25         1      1    H1         1        2        3
# 1            25         2      1    H1         1        2        3
# 2            25         3      1    H1         1        2        3
# 3            25         4      1    H1         1        2        3
# 4            25         5      1    H1         1        2        3
# ...         ...       ...    ...   ...       ...      ...      ...
# 216721    24676        21      7    P0         3        1        2
# 216722    24676        22      7    P0         3        1        2
# 216723    24676        23      7    P0         3        1        2
# 216724    24676        24      7    P0         3        1        2
# 216725    24676        25      7    P0         3        1        2
#
#         REGULACION  SEXO  TIPOPAIS CNO1  RESPONSA  ESTU  ANOANTI  MESANTI  \
# 0                2     1         1   N0         0     3       28       10
# ...

# %%
salarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216726 entries, 0 to 216725
# Data columns (total 1 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   RETRINOIN  216726 non-null  float64
# dtypes: float64(1)
# memory usage: 1.7 MB

# %%
salarios = sal[['RETRINOIN']]

# %%
salarios.sort_values(by='RETRINOIN', inplace=True)
salarios
# Out:
# C:\Users\Gonzalo\AppData\Local\Temp\ipykernel_32176\4287919880.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salarios.sort_values(by='RETRINOIN', inplace=True)
#         RETRINOIN
# 127085       0.00
# 20324        0.00
# 149382       0.00
# 30905        0.00
# 58895        0.00
# ...           ...
# 81200  2192967.20
# 177987 3903390.45
# 177988 4021902.63
# 177990 4153877.05
# 177985 4225998.36
#
# [216726 rows x 1 columns]

# %%
sal1 = salarios[salarios['RETRINOIN']>1000]
sal2 = salarios[salarios['RETRINOIN']>5000]

# %%
salarios[salarios['RETRINOIN']<10000]
# Out:
#         RETRINOIN
# 127085       0.00
# 20324        0.00
# 149382       0.00
# 30905        0.00
# 58895        0.00
# ...           ...
# 79632     9999.92
# 142652    9999.92
# 74225     9999.96
# 66010     9999.99
# 155249    9999.99
#
# [36040 rows x 1 columns]

# %%
salarios['RETRINOIN'].describe()
# Out:
# count    216726.00
# mean      26183.44
# std       32413.24
# min           0.00
# 25%       13320.08
# 50%       21098.25
# 75%       32364.61
# max     4225998.36
# Name: RETRINOIN, dtype: float64

# %%
salarios.to_csv('SALARIOS_TODOS.csv',index=False)
sal1.to_csv('SALARIOS_1000.csv',index=False)
sal2.to_csv('SALARIOS_5000.csv',index=False)
